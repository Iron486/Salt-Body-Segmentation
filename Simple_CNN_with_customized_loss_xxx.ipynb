# %% [markdown]
# ##   <font color='Lime'>Import libraries</font>

# %%
import os
import sys
import random
import warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import cv2

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
# Set some parameters
im_width = 128
im_height = 128
im_chan = 1
path_train = r'C:\\Users\diego\OneDrive\Desktop\DS\seismic_segmentation\train'
path_test = r'C:\\Users\diego\OneDrive\Desktop\DS\seismic_segmentation\test'

# %% [markdown]
# ##   <font color='Lime'>Data Analysis</font>

# %%
ids= ['1f1cc6b3a4','5b7c160d0d','6c40978ddf','7dfdf6eeb8','7e5a6e5013']
plt.figure(figsize=(20,10))
for j, img_name in enumerate(ids):
    q = j+1
    img = load_img(os.path.join(r'C:\\Users\diego\OneDrive\Desktop\DS\seismic_segmentation\train\images', img_name + '.png'))
    img_mask = load_img(os.path.join(r'C:\\Users\diego\OneDrive\Desktop\DS\seismic_segmentation\train\masks', img_name +'.png'))

    plt.subplot(1,2*(1+len(ids)),q*2-1)
    plt.imshow(img)
    plt.subplot(1,2*(1+len(ids)),q*2)
    plt.imshow(img_mask)
plt.show()

# %%
train_ids = next(os.walk(os.path.join(path_train,"images")))[2]
test_ids = next(os.walk(os.path.join(path_test,"images")))[2]

# %%
# Get and resize train images and masks
X_train = np.zeros((len(train_ids), im_height, im_width, im_chan), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), im_height, im_width, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm_notebook(enumerate(train_ids), total=len(train_ids)):
    path = path_train
    img = load_img(path + '/images/' + id_)
    x = img_to_array(img)[:,:,1]
    x = resize(x, (128, 128, 1), mode='constant', preserve_range=True)
    X_train[n] = x
    mask = img_to_array(load_img(path + '/masks/' + id_))[:,:,1]
    Y_train[n] = resize(mask, (128, 128, 1), mode='constant', preserve_range=True)

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# <ipython-input-74-ebd0e7c9c5c8>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Y_train = np.zeros((len(train_ids), im_height, im_width, 1), dtype=np.bool)
# <ipython-input-74-ebd0e7c9c5c8>:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n, id_ in tqdm_notebook(enumerate(train_ids), total=len(train_ids)):
#   0%|          | 0/4000 [00:00<?, ?it/s]
# Done!

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
plt.imshow(np.dstack((X_train[ix],X_train[ix],X_train[ix])))
plt.show()
tmp = np.squeeze(Y_train[ix]).astype(np.float32)
plt.imshow(np.dstack((tmp,tmp,tmp)))
plt.show()

# %% [markdown]
# ##  <font color='Lime'>Train-validation split</font>

# %%
from sklearn.model_selection import train_test_split

X_train,X_val,y_train,y_val = train_test_split(X_train,Y_train, test_size=0.1,random_state=42)

# %% [markdown]
# ##  <font color='Lime'>Train the model</font>

# %%
def Intersection_over_Union(y_true, y_pred, threshold=0.5):
    y_pred = K.squeeze(tf.cast(y_pred > threshold,tf.int32), -1)
    y_true = K.cast(y_true[..., 0], K.floatx())
    y_pred = K.cast(y_pred, K.floatx())
    truth_areas = K.sum(y_true, axis=[1, 2])
    pred_areas = K.sum(y_pred, axis=[1, 2])
    intersection = K.sum(y_true * y_pred, axis=[1, 2])
    union = K.clip(truth_areas + pred_areas - intersection, 1e-9, 128 * 128)
    check = K.map_fn(lambda x: K.equal(x, 0), truth_areas + pred_areas, dtype=tf.bool) #images with no predicted and true salt bodies
    p = intersection / union #ratio for each image
    iou = K.switch(check, p + 1., p) # put 1 for images where no salt bodies were found 

    prec = K.map_fn(lambda x: K.mean(K.greater(x, np.arange(0.5, 1.0, 0.05))), iou, dtype=tf.float32) 
    #does each image have a iou greater than threshold? if so, the image iou is used to calculate the mean
    prec_iou = K.mean(prec)
    return prec_iou

# %%
#!pip install pydot
#!pip install graphviz
#!pip install pydot
#!pip install pydotplus
# !conda install graphviz
#conda install pydotplus

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input
#from tensorflow.keras.utils.vis_utils import plot_model
from keras.utils.vis_utils import plot_model
inputs = Input((im_height, im_width, im_chan))
s = Lambda(lambda x: x / 255)(inputs)

c1 = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(s)
c1 = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(p1)
c2 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

c3 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(p2)
c3 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

c4 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(p3)
c4 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)

c5 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p4)
c5 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c5)

u6 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u6)
c6 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c6)

u7 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(u7)
c7 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c7)

u8 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(u8)
c8 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(c8)

u9 = tf.keras.layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(u9)
c9 = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c9)

outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

model = Model(inputs=[inputs], outputs=[outputs])


tf.keras.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
#tf.float32

tf.random.set_seed(42)
#
#import keras
#from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input
#from tensorflow.keras.layers import Input, Dense
# Build U-Net model
'''
model = keras.models.Sequential()
#model.add(keras.layers.Input(im_height, im_width, im_chan))
model.add(Lambda(lambda x: x / 255)) #pixels normalization

model.add(Conv2D(8, (3, 3), activation='relu', padding='same',input_shape=(im_height, im_width, im_chan)))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))

model2 = keras.models.Sequential()

model.add( Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add( MaxPooling2D(pool_size=(2, 2)))

model.add( Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add( Conv2D(128, (3, 3), activation='relu', padding='same'))

model.add( Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same'))
model.add( keras.layers.merge.concatenate([u6, c4]))
model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add( Conv2D(64, (3, 3), activation='relu', padding='same'))

model.add(Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same'))
model.add( Concatenate([u7, c3]))
model.add( Conv2D(32, (3, 3), activation='relu', padding='same'))
model.add( Conv2D(32, (3, 3), activation='relu', padding='same'))

model.add( Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same'))
model.add( concatenate([u8, c2]))
model.add( Conv2D(16, (3, 3), activation='relu', padding='same'))
model.add( Conv2D(16, (3, 3), activation='relu', padding='same'))

model.add(  Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same'))
model.add(concatenate([u9, c1], axis=3))
model.add(  Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(  Conv2D(8, (3, 3), activation='relu', padding='same'))

model.add(Conv2D(1, (1, 1), activation='sigmoid'))
'''
inputs = Input((im_height, im_width, im_chan))
s = Lambda(lambda x: x / 255)(inputs)

c1 = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(s)
c1 = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(p1)
c2 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

c3 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(p2)
c3 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

c4 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(p3)
c4 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)

c5 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p4)
c5 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c5)

u6 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u6)
c6 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c6)

u7 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(u7)
c7 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c7)

u8 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(u8)
c8 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(c8)

u9 = tf.keras.layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(u9)
c9 = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c9)

outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

model = Model(inputs=[inputs], outputs=[outputs])




#import tensorflow.keras.metrics 
#model = Model(inputs=[inputs], outputs=[outputs])
#model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[tf.keras.metrics.MeanIoU(num_classes=2)])# metrics=[tf.keras.metrics.MeanIoU(num_classes=2)])
#model.summary()
from tensorflow.keras.optimizers import schedules
lr_schedule = schedules.ExponentialDecay(
    initial_learning_rate=0.0004,
    decay_steps=8000,
    decay_rate=0.97)

opt = Adam(
    learning_rate=lr_schedule,
    epsilon=1e-08)


model.compile(optimizer=opt, loss='binary_crossentropy', metrics=[Intersection_over_Union])# metrics=[tf.keras.metrics.MeanIoU(num_classes=2)])

# summarize the model
model.summary()

earlystopper = EarlyStopping(patience=15, verbose=1,restore_best_weights=True)
#tf.cast(X_train, tf.int32)
#tf.cast( Y_train, tf.int32)
#checkpointer = ModelCheckpoint('model-tgs-salt-1.h5', verbose=1, save_best_only=True)

history=model.fit(X_train, y_train,validation_data = (X_val,y_val), batch_size=12, epochs=22, 
                    callbacks=[earlystopper])
#early_stopping_cb=keras.callbacks.EarlyStopping(patience=15,restore_best_weights=True)


#history=model.fit(X_train ,y_train,validation_data = (X_test,y_test),epochs=180,
   # batch_size=9,callbacks=[early_stopping_cb])
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# tf.math.truediv_8 (TFOpLambda)  (None, 128, 128, 1)  0           input_9[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 128, 128, 8)  80          tf.math.truediv_8[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 128, 128, 8)  584         conv2d_152[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_32 (MaxPooling2D) (None, 64, 64, 8)    0           conv2d_153[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 64, 64, 16)   1168        max_pooling2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 64, 64, 16)   2320        conv2d_154[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_33 (MaxPooling2D) (None, 32, 32, 16)   0           conv2d_155[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 32, 32, 32)   4640        max_pooling2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 32, 32, 32)   9248        conv2d_156[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_34 (MaxPooling2D) (None, 16, 16, 32)   0           conv2d_157[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 16, 16, 64)   18496       max_pooling2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 16, 16, 64)   36928       conv2d_158[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_35 (MaxPooling2D) (None, 8, 8, 64)     0           conv2d_159[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 8, 8, 128)    73856       max_pooling2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 8, 8, 128)    147584      conv2d_160[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_32 (Conv2DTran (None, 16, 16, 64)   32832       conv2d_161[0][0]
# __________________________________________________________________________________________________
# concatenate_32 (Concatenate)    (None, 16, 16, 128)  0           conv2d_transpose_32[0][0]
#                                                                  conv2d_159[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 16, 16, 64)   73792       concatenate_32[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 16, 16, 64)   36928       conv2d_162[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_33 (Conv2DTran (None, 32, 32, 32)   8224        conv2d_163[0][0]
# __________________________________________________________________________________________________
# concatenate_33 (Concatenate)    (None, 32, 32, 64)   0           conv2d_transpose_33[0][0]
#                                                                  conv2d_157[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 32, 32, 32)   18464       concatenate_33[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 32, 32, 32)   9248        conv2d_164[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_34 (Conv2DTran (None, 64, 64, 16)   2064        conv2d_165[0][0]
# __________________________________________________________________________________________________
# concatenate_34 (Concatenate)    (None, 64, 64, 32)   0           conv2d_transpose_34[0][0]
#                                                                  conv2d_155[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 64, 64, 16)   4624        concatenate_34[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 64, 64, 16)   2320        conv2d_166[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_35 (Conv2DTran (None, 128, 128, 8)  520         conv2d_167[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 128, 128, 16) 0           conv2d_transpose_35[0][0]
#                                                                  conv2d_153[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 128, 128, 8)  1160        concatenate_35[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 128, 128, 8)  584         conv2d_168[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 128, 128, 1)  9           conv2d_169[0][0]
# ==================================================================================================
# Total params: 485,673
# Trainable params: 485,673
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/22
# 300/300 [==============================] - 9s 27ms/step - loss: 0.5697 - Intersection_over_Union: 0.0794 - val_loss: 0.4563 - val_Intersection_over_Union: 0.0686
# Epoch 2/22
# 300/300 [==============================] - 15s 50ms/step - loss: 0.4138 - Intersection_over_Union: 0.2694 - val_loss: 0.3704 - val_Intersection_over_Union: 0.5642
# Epoch 3/22
# 300/300 [==============================] - 15s 51ms/step - loss: 0.3419 - Intersection_over_Union: 0.5377 - val_loss: 0.3048 - val_Intersection_over_Union: 0.5902
# Epoch 4/22
# 300/300 [==============================] - 15s 51ms/step - loss: 0.3139 - Intersection_over_Union: 0.5696 - val_loss: 0.3278 - val_Intersection_over_Union: 0.5527
# Epoch 5/22
# 300/300 [==============================] - 15s 51ms/step - loss: 0.3019 - Intersection_over_Union: 0.5768 - val_loss: 0.2716 - val_Intersection_over_Union: 0.6341
# Epoch 6/22
# 300/300 [==============================] - 15s 51ms/step - loss: 0.2828 - Intersection_over_Union: 0.5894 - val_loss: 0.3246 - val_Intersection_over_Union: 0.5993
# Epoch 7/22
# 300/300 [==============================] - 15s 51ms/step - loss: 0.2730 - Intersection_over_Union: 0.5939 - val_loss: 0.2586 - val_Intersection_over_Union: 0.6363
# Epoch 8/22
# 300/300 [==============================] - 15s 51ms/step - loss: 0.2542 - Intersection_over_Union: 0.6056 - val_loss: 0.2309 - val_Intersection_over_Union: 0.6627
# Epoch 9/22
# 300/300 [==============================] - 15s 51ms/step - loss: 0.2400 - Intersection_over_Union: 0.6157 - val_loss: 0.2287 - val_Intersection_over_Union: 0.6681
# Epoch 10/22
# 300/300 [==============================] - 15s 51ms/step - loss: 0.2318 - Intersection_over_Union: 0.6153 - val_loss: 0.2259 - val_Intersection_over_Union: 0.6549
# Epoch 11/22
# 300/300 [==============================] - 15s 51ms/step - loss: 0.2178 - Intersection_over_Union: 0.6298 - val_loss: 0.2064 - val_Intersection_over_Union: 0.6453
# Epoch 12/22
# 300/300 [==============================] - 16s 52ms/step - loss: 0.2057 - Intersection_over_Union: 0.6346 - val_loss: 0.2052 - val_Intersection_over_Union: 0.6765
# Epoch 13/22
# 300/300 [==============================] - 16s 54ms/step - loss: 0.2030 - Intersection_over_Union: 0.6304 - val_loss: 0.2004 - val_Intersection_over_Union: 0.6949
# Epoch 14/22
# 300/300 [==============================] - 16s 53ms/step - loss: 0.1942 - Intersection_over_Union: 0.6426 - val_loss: 0.1898 - val_Intersection_over_Union: 0.6779
# Epoch 15/22
# 300/300 [==============================] - 15s 51ms/step - loss: 0.1777 - Intersection_over_Union: 0.6501 - val_loss: 0.1845 - val_Intersection_over_Union: 0.7115
# Epoch 16/22
# 300/300 [==============================] - 15s 51ms/step - loss: 0.1706 - Intersection_over_Union: 0.6596 - val_loss: 0.1910 - val_Intersection_over_Union: 0.6292
# Epoch 17/22
# 300/300 [==============================] - 15s 51ms/step - loss: 0.1683 - Intersection_over_Union: 0.6618 - val_loss: 0.2131 - val_Intersection_over_Union: 0.7157
# Epoch 18/22
# 300/300 [==============================] - 15s 51ms/step - loss: 0.1610 - Intersection_over_Union: 0.6715 - val_loss: 0.1883 - val_Intersection_over_Union: 0.6605
# Epoch 19/22
# 300/300 [==============================] - 16s 52ms/step - loss: 0.1606 - Intersection_over_Union: 0.6666 - val_loss: 0.1850 - val_Intersection_over_Union: 0.6975
# Epoch 20/22
# 300/300 [==============================] - 16s 52ms/step - loss: 0.1485 - Intersection_over_Union: 0.6761 - val_loss: 0.1764 - val_Intersection_over_Union: 0.6752
# Epoch 21/22
# 300/300 [==============================] - 15s 52ms/step - loss: 0.1453 - Intersection_over_Union: 0.6772 - val_loss: 0.1985 - val_Intersection_over_Union: 0.7042
# Epoch 22/22
# 300/300 [==============================] - 16s 52ms/step - loss: 0.1344 - Intersection_over_Union: 0.6846 - val_loss: 0.1740 - val_Intersection_over_Union: 0.6716

# %% [markdown]
# ##  <font color='Lime'>Save the model and plot accuracy and loss</font>

# %%
print(os.getcwd())

#save the model
name='CNN_first_model'
#os.mkdir('models/')
if  os.path.exists(os.path.join(os.getcwd(),'models/'))==False:
    os.mkdir('models/')
model.save(os.path.join('models/',name+'.h5'))
model.save_weights(os.path.join('models/',name+'_weights.h5'))
#plt.gca().set_xlim(0,33)
   
    
#loss, accuracy = model.evaluate(X_test,y_test)
if  os.path.exists(os.path.join(os.getcwd(),'plots/'))==False:
    os.mkdir('plots/')

pd.DataFrame(history.history).plot(figsize=(8, 5))

plt.title('Model Loss and Accuracy',fontsize=14,y=1.03 )
plt.grid( True )    

plt.ylabel('Loss and Accuracy',labelpad=7,fontsize=10)    
plt.xlabel('Epochs',labelpad=7,fontsize=10)   
plt.gca().set_ylim(0,1)
plt.savefig(os.path.join('plots/',name+'.png'), dpi=500, bbox_inches='tight',facecolor=(1, 1, 1) )

#evaluate loss and accuracy
loss, accuracy = model.evaluate(X_val,y_val)
#plot loss and accuracy

#plt.gca().set_ylim(0,1)
#plt.grid(True)

#print accuracy    
print('Accuracy: %f' % (accuracy*100),'Loss: %f' % (loss))
# Out:
# C:\Users\diego\OneDrive\Desktop\DS\seismic_segmentation
# 13/13 [==============================] - 1s 64ms/step - loss: 0.1740 - Intersection_over_Union: 0.6762
# Accuracy: 67.620188 Loss: 0.174045

# %% [markdown]
# ##  <font color='Lime'>Accuracy and Loss</font>

# %%
print(f'accuracy : {round(accuracy*100,3)} \n loss : {round(loss,3)}')
# Out:
# accuracy : 67.62
#  loss : 0.174

# %%
# visualize activation functions
for i, layer in enumerate (model.layers):
    print (i, layer)
    try:
        print ("    ",layer.activation)
    except AttributeError:
        print('   no activation attribute')
#specific info about each layer
for i in range(len(model.layers)):
    print(f'{i}   {model.layers[i]}: \n{model.layers[i].get_config()} \n')
#info about optimizers
model.optimizer.get_config()
# Out:
# 0 <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x000002CF568D1430>
#    no activation attribute
# 1 <tensorflow.python.keras.layers.core.TFOpLambda object at 0x000002CF527F8FD0>
#    no activation attribute
# 2 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF567D2100>
#      <function relu at 0x000002CF4FB44040>
# 3 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568D1640>
#      <function relu at 0x000002CF4FB44040>
# 4 <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002CF568F48E0>
#    no activation attribute
# 5 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568F4BE0>
#      <function relu at 0x000002CF4FB44040>
# 6 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568CF430>
#      <function relu at 0x000002CF4FB44040>
# 7 <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002CF568FA5B0>
#    no activation attribute
# 8 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568FA8B0>
#      <function relu at 0x000002CF4FB44040>
# 9 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568FAD30>
#      <function relu at 0x000002CF4FB44040>
# 10 <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002CF568F4E50>
#    no activation attribute
# 11 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568FD580>
#      <function relu at 0x000002CF4FB44040>
# 12 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568FDA00>
#      <function relu at 0x000002CF4FB44040>
# 13 <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002CF568FDF10>
#    no activation attribute
# 14 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF56900250>
#      <function relu at 0x000002CF4FB44040>
# 15 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF569006D0>
#      <function relu at 0x000002CF4FB44040>
# 16 <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000002CF56900BE0>
#      <function linear at 0x000002CF4FB44700>
# 17 <tensorflow.python.keras.layers.merge.Concatenate object at 0x000002CF569051F0>
#    no activation attribute
# 18 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568FAFD0>
#      <function relu at 0x000002CF4FB44040>
# 19 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF56905850>
#      <function relu at 0x000002CF4FB44040>
# 20 <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000002CF56905D60>
#      <function linear at 0x000002CF4FB44700>
# 21 <tensorflow.python.keras.layers.merge.Concatenate object at 0x000002CF56909370>
#    no activation attribute
# 22 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF56869640>
#      <function relu at 0x000002CF4FB44040>
# 23 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF569099D0>
#      <function relu at 0x000002CF4FB44040>
# 24 <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000002CF56909EE0>
#      <function linear at 0x000002CF4FB44700>
# 25 <tensorflow.python.keras.layers.merge.Concatenate object at 0x000002CF5690D4F0>
#    no activation attribute
# 26 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF56900EE0>
#      <function relu at 0x000002CF4FB44040>
# 27 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF5690DB50>
#      <function relu at 0x000002CF4FB44040>
# 28 <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000002CF56905F70>
#      <function linear at 0x000002CF4FB44700>
# 29 <tensorflow.python.keras.layers.merge.Concatenate object at 0x000002CF569103A0>
#    no activation attribute
# 30 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF569106A0>
#      <function relu at 0x000002CF4FB44040>
# 31 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF56910CD0>
#      <function relu at 0x000002CF4FB44040>
# 32 <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF5690DE50>
#      <function sigmoid at 0x000002CF4FB443A0>
# 0   <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x000002CF568D1430>:
# {'batch_input_shape': (None, 128, 128, 1), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input_4'}
#
# 1   <tensorflow.python.keras.layers.core.TFOpLambda object at 0x000002CF527F8FD0>:
# {'name': 'tf.math.truediv_3', 'trainable': True, 'dtype': 'float32', 'function': 'math.truediv'}
#
# 2   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF567D2100>:
# {'name': 'conv2d_57', 'trainable': True, 'dtype': 'float32', 'filters': 8, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 3   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568D1640>:
# {'name': 'conv2d_58', 'trainable': True, 'dtype': 'float32', 'filters': 8, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 4   <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002CF568F48E0>:
# {'name': 'max_pooling2d_12', 'trainable': True, 'dtype': 'float32', 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}
#
# 5   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568F4BE0>:
# {'name': 'conv2d_59', 'trainable': True, 'dtype': 'float32', 'filters': 16, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 6   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568CF430>:
# {'name': 'conv2d_60', 'trainable': True, 'dtype': 'float32', 'filters': 16, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 7   <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002CF568FA5B0>:
# {'name': 'max_pooling2d_13', 'trainable': True, 'dtype': 'float32', 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}
#
# 8   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568FA8B0>:
# {'name': 'conv2d_61', 'trainable': True, 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 9   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568FAD30>:
# {'name': 'conv2d_62', 'trainable': True, 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 10   <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002CF568F4E50>:
# {'name': 'max_pooling2d_14', 'trainable': True, 'dtype': 'float32', 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}
#
# 11   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568FD580>:
# {'name': 'conv2d_63', 'trainable': True, 'dtype': 'float32', 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 12   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568FDA00>:
# {'name': 'conv2d_64', 'trainable': True, 'dtype': 'float32', 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 13   <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x000002CF568FDF10>:
# {'name': 'max_pooling2d_15', 'trainable': True, 'dtype': 'float32', 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}
#
# 14   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF56900250>:
# {'name': 'conv2d_65', 'trainable': True, 'dtype': 'float32', 'filters': 128, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 15   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF569006D0>:
# {'name': 'conv2d_66', 'trainable': True, 'dtype': 'float32', 'filters': 128, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 16   <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000002CF56900BE0>:
# {'name': 'conv2d_transpose_12', 'trainable': True, 'dtype': 'float32', 'filters': 64, 'kernel_size': (2, 2), 'strides': (2, 2), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None, 'output_padding': None}
#
# 17   <tensorflow.python.keras.layers.merge.Concatenate object at 0x000002CF569051F0>:
# {'name': 'concatenate_12', 'trainable': True, 'dtype': 'float32', 'axis': -1}
#
# 18   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF568FAFD0>:
# {'name': 'conv2d_67', 'trainable': True, 'dtype': 'float32', 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 19   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF56905850>:
# {'name': 'conv2d_68', 'trainable': True, 'dtype': 'float32', 'filters': 64, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 20   <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000002CF56905D60>:
# {'name': 'conv2d_transpose_13', 'trainable': True, 'dtype': 'float32', 'filters': 32, 'kernel_size': (2, 2), 'strides': (2, 2), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None, 'output_padding': None}
#
# 21   <tensorflow.python.keras.layers.merge.Concatenate object at 0x000002CF56909370>:
# {'name': 'concatenate_13', 'trainable': True, 'dtype': 'float32', 'axis': -1}
#
# 22   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF56869640>:
# {'name': 'conv2d_69', 'trainable': True, 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 23   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF569099D0>:
# {'name': 'conv2d_70', 'trainable': True, 'dtype': 'float32', 'filters': 32, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 24   <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000002CF56909EE0>:
# {'name': 'conv2d_transpose_14', 'trainable': True, 'dtype': 'float32', 'filters': 16, 'kernel_size': (2, 2), 'strides': (2, 2), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None, 'output_padding': None}
#
# 25   <tensorflow.python.keras.layers.merge.Concatenate object at 0x000002CF5690D4F0>:
# {'name': 'concatenate_14', 'trainable': True, 'dtype': 'float32', 'axis': -1}
#
# 26   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF56900EE0>:
# {'name': 'conv2d_71', 'trainable': True, 'dtype': 'float32', 'filters': 16, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 27   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF5690DB50>:
# {'name': 'conv2d_72', 'trainable': True, 'dtype': 'float32', 'filters': 16, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 28   <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x000002CF56905F70>:
# {'name': 'conv2d_transpose_15', 'trainable': True, 'dtype': 'float32', 'filters': 8, 'kernel_size': (2, 2), 'strides': (2, 2), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None, 'output_padding': None}
#
# 29   <tensorflow.python.keras.layers.merge.Concatenate object at 0x000002CF569103A0>:
# {'name': 'concatenate_15', 'trainable': True, 'dtype': 'float32', 'axis': 3}
#
# 30   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF569106A0>:
# {'name': 'conv2d_73', 'trainable': True, 'dtype': 'float32', 'filters': 8, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 31   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF56910CD0>:
# {'name': 'conv2d_74', 'trainable': True, 'dtype': 'float32', 'filters': 8, 'kernel_size': (3, 3), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
#
# 32   <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x000002CF5690DE50>:
# {'name': 'conv2d_75', 'trainable': True, 'dtype': 'float32', 'filters': 1, 'kernel_size': (1, 1), 'strides': (1, 1), 'padding': 'valid', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'class_name': 'GlorotUniform', 'config': {'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'name': 'Adam',
#  'learning_rate': {'class_name': 'ExponentialDecay',
#   'config': {'initial_learning_rate': 0.0004,
#    'decay_steps': 8000,
#    'decay_rate': 0.97,
#    'staircase': False,
#    'name': None}},
#  'decay': 0.0,
#  'beta_1': 0.9,
#  'beta_2': 0.999,
#  'epsilon': 1e-08,
#  'amsgrad': False}

# %% [markdown]
# ##  <font color='Lime'>Load the model </font>

# %%
inputs = Input((im_height, im_width, im_chan))
s = Lambda(lambda x: x / 255)(inputs)

c1 = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(s)
c1 = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(c1)

c2 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(p1)
c2 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(c2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(c2)

c3 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(p2)
c3 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(c3)

c4 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(p3)
c4 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c4)

c5 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p4)
c5 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c5)

u6 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u6)
c6 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c6)

u7 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(u7)
c7 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(c7)

u8 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(u8)
c8 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', padding='same')(c8)

u9 = tf.keras.layers.Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(u9)
c9 = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', padding='same')(c9)

outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

saved_model = Model(inputs=[inputs], outputs=[outputs])

saved_model.load_weights(os.path.join('models/',name+'_weights.h5'))

saved_model.compile(optimizer=opt, loss='binary_crossentropy', metrics=[Intersection_over_Union])

# %%
loss, accuracy = saved_model.evaluate(X_val,y_val)
# Out:
# 13/13 [==============================] - 2s 52ms/step - loss: 0.1740 - Intersection_over_Union: 0.6762

# %%
#here I plotted the images based on columns and z_max (defined by the user, but it should be a multiple of the # of columns)
#columns = 20
n_images=100
columns=10


images=X_val[:n_images]


#int(len(images)/columns)

fig,axes=plt.subplots(int(len(images)/columns),columns,figsize=(40,20))
fig.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.463, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
for i,ind in enumerate(images):
    #print(images_class)
    fig.suptitle(f'First {n_images} sections in the dataset',fontsize=26, x=0.2812,y=0.946)
    #print(j,image)
    axes[int(i/columns), i % columns].imshow(ind)
    #axes[int((i)*(len(ind)/columns)+(int(j/columns))),j % columns] #.set_title(f'{classes[i]}',pad=10)
#image_plotting(X_test[:1])
plt.savefig(os.path.join('plots/','100_images_in_the_dataset_white.png'), dpi=300,facecolor='w',bbox_inches='tight')

# %%
#here I plotted the images based on columns and z_max (defined by the user, but it should be a multiple of the # of columns)
columns = 10
fig,axes=plt.subplots(int(len(images)*len(images[0])/columns),columns,figsize=(40,20))
fig.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
for i,ind in enumerate(images):
    #print(images_class)
    fig.suptitle('Plot of some MRI images in the dataset',fontsize=47)
    for j, image in enumerate(ind):
        #print(j,image)
        axes[int((i)*(len(ind)/columns)+(int(j/columns))),j % columns].imshow(image)
        axes[int((i)*(len(ind)/columns)+(int(j/columns))),j % columns].set_title(f'{classes[i]}',pad=10)
#image_plotting(X_test[:1])
#plt.savefig(os.path.join('plots/','Some_MRI_images_in_the_dataset_white.png'), dpi=300,facecolor='w')

# %% [markdown]
# ##  <font color='Lime'>Test Data</font>

# %%
# Get and resize test images
X_test = np.zeros((len(test_ids), im_height, im_width, im_chan), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm_notebook(enumerate(test_ids), total=len(test_ids)):
    path = path_test
    img = load_img(path + '/images/' + id_)
    x = img_to_array(img)[:,:,1]
    sizes_test.append([x.shape[0], x.shape[1]])
    x = resize(x, (128, 128, 1), mode='constant', preserve_range=True)
    X_test[n] = x

print('Done!')
# Out:
# Getting and resizing test images ...
# <ipython-input-16-80c5a58b954f>:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n, id_ in tqdm_notebook(enumerate(test_ids), total=len(test_ids)):
#   0%|          | 0/18000 [00:00<?, ?it/s]
# Done!

# %%
preds_test = model.predict(X_test, verbose=1)

preds_test
# Out:
# 563/563 [==============================] - 18s 31ms/step
# array([[[[3.83190334e-01],
#          [3.52838486e-01],
#          [3.37151140e-01],
#          ...,
#          [1.38978764e-01],
#          [1.51785806e-01],
#          [1.70318246e-01]],
#
#         [[3.75383765e-01],
#          [3.26996028e-01],
#          [3.18244159e-01],
#          ...,
#          [1.41009063e-01],
#          [1.64451793e-01],
#          [1.78626806e-01]],
#
#         [[3.69198203e-01],
#          [3.39374036e-01],
#          [3.25556606e-01],
#          ...,
#          [1.36234388e-01],
#          [1.41641065e-01],
#          [1.29727036e-01]],
#
#         ...,
#
#         [[3.99674177e-01],
#          [4.01038468e-01],
#          [3.92514139e-01],
#          ...,
#          [1.95704922e-01],
#          [2.22376898e-01],
#          [2.04685226e-01]],
#
#         [[4.06744868e-01],
#          [3.86534810e-01],
#          [3.71732771e-01],
#          ...,
#          [1.99615672e-01],
#          [2.10665911e-01],
#          [1.69785649e-01]],
#
#         [[4.08921599e-01],
#          [4.10888910e-01],
#          [4.48539823e-01],
#          ...,
#          [1.85442924e-01],
#          [2.57094949e-01],
#          [1.97469950e-01]]],
#
#
#        [[[5.05807400e-01],
#          [5.25369287e-01],
#          [5.45160234e-01],
#          ...,
#          [2.75524080e-01],
#          [3.44488680e-01],
#          [3.17943841e-01]],
#
#         [[5.75951040e-01],
#          [5.95756054e-01],
#          [5.91648459e-01],
#          ...,
#          [3.02873105e-01],
#          [3.34966749e-01],
#          [3.28597337e-01]],
#
#         [[5.64283133e-01],
#          [5.43133974e-01],
#          [5.84294498e-01],
#          ...,
#          [3.26335192e-01],
#          [3.33840251e-01],
#          [3.27453166e-01]],
#
#         ...,
#
#         [[4.18592367e-17],
#          [1.42573869e-16],
#          [2.16001094e-18],
#          ...,
#          [2.29691405e-10],
#          [2.31550867e-09],
#          [1.50732526e-09]],
#
#         [[6.22629593e-14],
#          [4.20662317e-16],
#          [1.07361904e-19],
#          ...,
#          [4.23956648e-09],
#          [3.11679660e-09],
#          [9.26343446e-10]],
#
#         [[7.28463852e-14],
#          [5.61344881e-17],
#          [4.16264316e-17],
#          ...,
#          [1.70355285e-09],
#          [5.61253160e-07],
#          [1.73464691e-08]]],
#
#
#        [[[3.54132921e-01],
#          [3.14456642e-01],
#          [2.98654735e-01],
#          ...,
#          [2.20989972e-01],
#          [2.25311488e-01],
#          [2.40197107e-01]],
#
#         [[3.46478850e-01],
#          [2.93842733e-01],
#          [2.82867432e-01],
#          ...,
#          [2.09135577e-01],
#          [2.36346960e-01],
#          [2.53232062e-01]],
#
#         [[3.42446744e-01],
#          [3.13335449e-01],
#          [2.99933612e-01],
#          ...,
#          [1.94225311e-01],
#          [1.93557963e-01],
#          [1.96861997e-01]],
#
#         ...,
#
#         [[5.36789834e-01],
#          [5.48271894e-01],
#          [5.46535850e-01],
#          ...,
#          [2.55106151e-01],
#          [2.71983266e-01],
#          [2.42971823e-01]],
#
#         [[5.47501922e-01],
#          [5.17175436e-01],
#          [4.76921797e-01],
#          ...,
#          [2.52981246e-01],
#          [2.49616727e-01],
#          [2.09888667e-01]],
#
#         [[5.54996669e-01],
#          [5.69894969e-01],
#          [5.97626925e-01],
#          ...,
#          [2.46849984e-01],
#          [3.01670313e-01],
#          [2.50925541e-01]]],
#
#
#        ...,
#
#
#        [[[2.54480895e-02],
#          [1.34841548e-02],
#          [1.10620353e-02],
#          ...,
#          [1.16197169e-02],
#          [1.52686983e-02],
#          [2.09558643e-02]],
#
#         [[4.07866612e-02],
#          [1.11043369e-02],
#          [8.03552847e-03],
#          ...,
#          [1.48849729e-02],
#          [2.29316484e-02],
#          [3.89662422e-02]],
#
#         [[2.89550312e-02],
#          [1.31900795e-02],
#          [6.97926478e-03],
#          ...,
#          [1.24364169e-02],
#          [1.35228466e-02],
#          [1.39473332e-02]],
#
#         ...,
#
#         [[8.78172457e-01],
#          [8.47077429e-01],
#          [9.14494812e-01],
#          ...,
#          [8.20049122e-02],
#          [9.92509276e-02],
#          [8.53681639e-02]],
#
#         [[9.08028007e-01],
#          [9.31080520e-01],
#          [8.89516354e-01],
#          ...,
#          [9.03427750e-02],
#          [8.93750936e-02],
#          [6.81815743e-02]],
#
#         [[7.62349844e-01],
#          [8.36421311e-01],
#          [8.73734891e-01],
#          ...,
#          [7.92507306e-02],
#          [1.49030253e-01],
#          [9.45099443e-02]]],
#
#
#        [[[2.54187703e-01],
#          [2.04135686e-01],
#          [1.97542310e-01],
#          ...,
#          [6.08103812e-01],
#          [6.15466356e-01],
#          [6.01950347e-01]],
#
#         [[2.56440461e-01],
#          [1.82394877e-01],
#          [1.69346973e-01],
#          ...,
#          [6.46454096e-01],
#          [6.12587094e-01],
#          [5.90513170e-01]],
#
#         [[2.34011546e-01],
#          [1.88420057e-01],
#          [1.60016730e-01],
#          ...,
#          [5.75008273e-01],
#          [5.49947619e-01],
#          [5.54019749e-01]],
#
#         ...,
#
#         [[9.07589942e-02],
#          [8.63502175e-02],
#          [7.32327998e-02],
#          ...,
#          [2.38318473e-01],
#          [2.66512662e-01],
#          [2.51334697e-01]],
#
#         [[1.26658440e-01],
#          [9.38988626e-02],
#          [5.80101721e-02],
#          ...,
#          [2.39980146e-01],
#          [2.54451066e-01],
#          [2.10306749e-01]],
#
#         [[1.27103448e-01],
#          [8.44565183e-02],
#          [9.43590403e-02],
#          ...,
#          [2.23321155e-01],
#          [2.90899158e-01],
#          [2.35756427e-01]]],
#
#
#        [[[6.80253625e-01],
#          [8.43841493e-01],
#          [9.39232528e-01],
#          ...,
#          [1.96281701e-01],
#          [2.06517398e-01],
#          [2.18217731e-01]],
#
#         [[9.00279462e-01],
#          [9.28080082e-01],
#          [9.24494326e-01],
#          ...,
#          [1.79189354e-01],
#          [2.03768268e-01],
#          [2.15520233e-01]],
#
#         [[9.08012807e-01],
#          [9.02850151e-01],
#          [9.71249700e-01],
#          ...,
#          [1.73568115e-01],
#          [1.77932560e-01],
#          [1.66345209e-01]],
#
#         ...,
#
#         [[3.13852936e-01],
#          [3.16874683e-01],
#          [3.04220945e-01],
#          ...,
#          [4.19604704e-02],
#          [5.37866503e-02],
#          [4.30336408e-02]],
#
#         [[3.43073338e-01],
#          [3.27013820e-01],
#          [2.92611688e-01],
#          ...,
#          [4.83355261e-02],
#          [4.58021387e-02],
#          [3.29731442e-02]],
#
#         [[3.46607834e-01],
#          [3.20599228e-01],
#          [3.80405337e-01],
#          ...,
#          [4.20370027e-02],
#          [9.59263369e-02],
#          [5.25458343e-02]]]], dtype=float32)

# %%
# Create list of upsampled test masks
preds_test_upsampled = []
for i in tnrange(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# <ipython-input-85-b9d262d27614>:3: TqdmDeprecationWarning: Please use `tqdm.notebook.trange` instead of `tqdm.tnrange`
#   for i in tnrange(len(preds_test)):
#   0%|          | 0/18000 [00:00<?, ?it/s]

# %%
preds_test_upsampled[0].shape
# Out:
# (101, 101)

# %% [markdown]
# ##  <font color='Lime'>Prepare Submission</font>

# %%
def RLenc(img, order='F', format=True):
    """
    img is binary mask image, shape (r,c)
    order is down-then-right, i.e. Fortran
    format determines if the order needs to be preformatted (according to submission rules) or not

    returns run length as an array or string (if format is True)
    """
    bytes = img.reshape(img.shape[0] * img.shape[1], order=order)
    runs = []  ## list of run lengths
    r = 0  ## the current run length
    pos = 1  ## count starts from 1 per WK
    for c in bytes:
        if (c == 0):
            if r != 0:
                runs.append((pos, r))
                pos += r
                r = 0
            pos += 1
        else:
            r += 1

    # if last run is unsaved (i.e. data ends with 1)
    if r != 0:
        runs.append((pos, r))
        pos += r
        r = 0

    if format:
        z = ''

        for rr in runs:
            z += '{} {} '.format(rr[0], rr[1])
        return z[:-1]
    else:
        return runs

pred_dict = {fn[:-4]:RLenc(np.round(preds_test_upsampled[i])) for i,fn in tqdm_notebook(enumerate(test_ids))}
# Out:
# <ipython-input-90-6ceb950ee2b3>:38: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   pred_dict = {fn[:-4]:RLenc(np.round(preds_test_upsampled[i])) for i,fn in tqdm_notebook(enumerate(test_ids))}
# 0it [00:00, ?it/s]

# %%
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv('submission_simpleCNN.csv')
